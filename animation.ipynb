# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## importing and reading data

# %%
df= pd.read_csv('Top 50 Animation Movies and TV Shows.csv')
df
# Out:
#     Ranking                                     Name         Year  Minutes  \
# 0       1.0                                Big Mouth     (2017– )   30 min
# 1       2.0                             The Bad Guys       (2022)  100 min
# 2       3.0                             Chainsaw Man     (2022– )      NaN
# 3       4.0                           Rick and Morty     (2013– )   23 min
# 4       5.0                             Disenchanted       (2022)      NaN
# 5       6.0                                Zootopia+     (2022– )      NaN
# 6       7.0             Star Wars: Tales of the Jedi     (2022– )   15 min
# 7       8.0                      One Piece Film: Red       (2022)  115 min
# 8       9.0                               Family Guy     (1999– )   22 min
# 9      10.0                           Wendell & Wild       (2022)  105 min
# 10     11.0                             The Simpsons     (1989– )   22 min
# ...

# %% [markdown]
# ## What is the number of observations in the dataset?

# %%
df.shape[0]
# Out:
# 50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ranking  50 non-null     float64
#  1   Name     50 non-null     object
#  2   Year     50 non-null     object
#  3   Minutes  46 non-null     object
#  4   genre    50 non-null     object
#  5   Rating   47 non-null     float64
#  6   Votes    47 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 2.9+ KB

# %% [markdown]
# ## What is the number of columns in the dataset?

# %%
df.shape[1]
# Out:
# 7

# %% [markdown]
# ##  Print the name of all the columns.

# %%
print("The names of all columns are "+str(df.columns))
# Out:
# The names of all columns are Index(['Ranking', 'Name', 'Year', 'Minutes', 'genre', 'Rating', 'Votes'], dtype='object')

# %% [markdown]
# ## How is the dataset indexed?

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %% [markdown]
# ## Which animation has the best and worst ranking?

# %%
df= df.sort_values('Ranking', ascending=False)
#df

# %%
print("The best ranking is for: "+ df.iloc[0,1])
print("The worst ranking is for: "+ df.iloc[-1,1])
# Out:
# The best ranking is for: SPY×FAMILY
# The worst ranking is for: Big Mouth

# %% [markdown]
# ## Which animation is the latest animation and what is its ranking?

# %%
df_new= df.sort_values('Year', ascending=False)
df_new
# Out:
#     Ranking                                     Name         Year  Minutes  \
# 13     14.0                                Pinocchio  (II) (2022)  117 min
# 42     43.0                                     Coco   (I) (2017)  105 min
# 33     34.0              The Super Mario Bros. Movie       (2023)      NaN
# 49     50.0                               SPY×FAMILY     (2022– )   24 min
# 15     16.0          Bleach: Thousand-Year Blood War     (2022– )   24 min
# 20     21.0                   Cyberpunk: Edgerunners     (2022– )   24 min
# 2       3.0                             Chainsaw Man     (2022– )      NaN
# 5       6.0                                Zootopia+     (2022– )      NaN
# 6       7.0             Star Wars: Tales of the Jedi     (2022– )   15 min
# 18     19.0                            Strange World       (2022)  102 min
# 16     17.0                    Lyle, Lyle, Crocodile       (2022)  106 min
# ...

# %%
print('the latest animation is '+df_new.iloc[0,1], 'and its ranking is: ')
print(df_new.iloc[0,0] )
# Out:
# the latest animation is Pinocchio and its ranking is:
# 14.0

# %%
df['count']=1
df.groupby(['genre']).count()['count']
# Out:
# genre
# Animation, Action, Adventure    18
# Animation, Action, Comedy        3
# Animation, Adventure, Comedy    12
# Animation, Adventure, Drama      1
# Animation, Comedy                5
# Animation, Comedy, Drama         1
# Animation, Comedy, Family        3
# Animation, Comedy, Romance       1
# Animation, Drama, Family         1
# Animation, Family                1
# Animation, Family, Fantasy       1
# Animation, Short, Action         2
# Animation, Short, Adventure      1
# Name: count, dtype: int64
